# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_dir = "/content/drive/MyDrive/DS340_Final_Project/speech_augmented_spectrograms_speed/speed_2"

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Image dimensions
IMG_HEIGHT, IMG_WIDTH = 128, 128
BATCH_SIZE = 32

# Create data generators
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

val_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 1155 images belonging to 8 classes.
# Found 285 images belonging to 8 classes.

# %%
from tensorflow.keras import layers
from tensorflow import keras
input_shape = (128, 128, 3)

# %%
model3 = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
        layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
        layers.Conv2D(128, (3, 3), activation='relu'),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5), # add dropout
        layers.Dense(128, activation='relu'),
        layers.Dense(8, activation='softmax'),
    ]
)

# %%
model3.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

import keras.callbacks
callbacks = [
    keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)  # Quit after 3 rounds of no validation loss improvement
]

model3.fit(train_generator, epochs=15, validation_data=val_generator, callbacks=callbacks) # add early stopping
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 411s 11s/step - accuracy: 0.1467 - loss: 3.2686 - val_accuracy: 0.1930 - val_loss: 1.9637
# Epoch 2/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 135ms/step - accuracy: 0.2665 - loss: 1.8564 - val_accuracy: 0.4246 - val_loss: 1.6262
# Epoch 3/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.5039 - loss: 1.3753 - val_accuracy: 0.4175 - val_loss: 1.7917
# Epoch 4/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 140ms/step - accuracy: 0.5844 - loss: 1.1948 - val_accuracy: 0.4807 - val_loss: 1.5359
# Epoch 5/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 142ms/step - accuracy: 0.7123 - loss: 0.8330 - val_accuracy: 0.4772 - val_loss: 1.4956
# Epoch 6/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - accuracy: 0.7750 - loss: 0.6453 - val_accuracy: 0.5333 - val_loss: 1.3433
# Epoch 7/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 134ms/step - accuracy: 0.8444 - loss: 0.4509 - val_accuracy: 0.4947 - val_loss: 1.5726
# Epoch 8/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 138ms/step - accuracy: 0.8763 - loss: 0.3617 - val_accuracy: 0.5649 - val_loss: 1.6204
# Epoch 9/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 142ms/step - accuracy: 0.9269 - loss: 0.2372 - val_accuracy: 0.5368 - val_loss: 1.6015

# %%
model5 = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
        layers.MaxPooling2D(pool_size=(2, 2)), # add max pooling
        layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(128, (3, 3), activation='relu'),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(256, (3, 3), activation='relu'), # add another layer
        layers.MaxPooling2D(pool_size=(2, 2)), # add max pooling
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(128, activation='relu'),
        layers.Dense(8, activation='softmax'),
    ]
)

# %%
model5.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

import keras.callbacks
callbacks = [
    keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)  # Quit after 3 rounds of no validation loss improvement
]

model5.fit(train_generator, epochs=15, validation_data=val_generator, callbacks=callbacks)
# Out:
# Epoch 1/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 13s 229ms/step - accuracy: 0.1214 - loss: 2.0764 - val_accuracy: 0.2211 - val_loss: 2.0326
# Epoch 2/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 141ms/step - accuracy: 0.2616 - loss: 1.9502 - val_accuracy: 0.2807 - val_loss: 1.8478
# Epoch 3/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.3554 - loss: 1.7107 - val_accuracy: 0.3509 - val_loss: 1.7724
# Epoch 4/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.4456 - loss: 1.5396 - val_accuracy: 0.4246 - val_loss: 1.6060
# Epoch 5/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 138ms/step - accuracy: 0.5071 - loss: 1.3556 - val_accuracy: 0.3333 - val_loss: 1.7758
# Epoch 6/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 138ms/step - accuracy: 0.5084 - loss: 1.2913 - val_accuracy: 0.3895 - val_loss: 1.5191
# Epoch 7/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 140ms/step - accuracy: 0.5523 - loss: 1.2200 - val_accuracy: 0.4175 - val_loss: 1.5974
# Epoch 8/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 138ms/step - accuracy: 0.5904 - loss: 1.1192 - val_accuracy: 0.3649 - val_loss: 1.8529
# Epoch 9/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.5865 - loss: 1.1017 - val_accuracy: 0.4667 - val_loss: 1.4703
# Epoch 10/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 139ms/step - accuracy: 0.6368 - loss: 0.9474 - val_accuracy: 0.4386 - val_loss: 1.4621
# Epoch 11/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 143ms/step - accuracy: 0.6654 - loss: 0.8920 - val_accuracy: 0.4632 - val_loss: 1.6166
# Epoch 12/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 142ms/step - accuracy: 0.7403 - loss: 0.7147 - val_accuracy: 0.4772 - val_loss: 1.5159
# Epoch 13/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 133ms/step - accuracy: 0.7505 - loss: 0.7064 - val_accuracy: 0.4632 - val_loss: 1.4430
# Epoch 14/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 138ms/step - accuracy: 0.7607 - loss: 0.6685 - val_accuracy: 0.3614 - val_loss: 2.2682
# Epoch 15/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.7436 - loss: 0.7099 - val_accuracy: 0.3754 - val_loss: 1.6166

# %%
from keras import regularizers
from keras import layers, regularizers, Sequential

model6 = Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation='relu', kernel_regularizer=regularizers.l2(1e-4)), # add l2 regularization
        # remove max pooling
        layers.Conv2D(64, kernel_size=(3, 3), activation='relu', kernel_regularizer=regularizers.l2(1e-4)), #add l2 regularization
        layers.MaxPooling2D(pool_size=(2, 2)),

        layers.Conv2D(128, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(1e-4)), #add l2 regularization
        # remove max pooling
        layers.Conv2D(256, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(1e-4)), #add l2 regularization
        layers.MaxPooling2D(pool_size=(2, 2)),

        layers.Flatten(),
        layers.Dropout(0.6), # change dropout from 0.5 to 0.6
        layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(1e-4)), #add l2 regularization
        layers.Dense(8, activation='softmax'),
    ]
)

# %%
model6.compile(loss="categorical_crossentropy", optimizer=keras.optimizers.Adam(learning_rate=1e-4), metrics=["accuracy"]) # modify learning rate

import keras.callbacks
callbacks = [
    keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)  # Quit after 3 rounds of no validation loss improvement
]

model6.fit(train_generator, epochs=15, validation_data=val_generator, callbacks=callbacks)
# Out:
# Epoch 1/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 15s 262ms/step - accuracy: 0.1630 - loss: 2.1087 - val_accuracy: 0.2632 - val_loss: 1.9328
# Epoch 2/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.3441 - loss: 1.8170 - val_accuracy: 0.3860 - val_loss: 1.7502
# Epoch 3/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.4962 - loss: 1.4676 - val_accuracy: 0.4667 - val_loss: 1.5533
# Epoch 4/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 139ms/step - accuracy: 0.5920 - loss: 1.2469 - val_accuracy: 0.4632 - val_loss: 1.4952
# Epoch 5/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 140ms/step - accuracy: 0.6360 - loss: 1.0511 - val_accuracy: 0.5649 - val_loss: 1.2758
# Epoch 6/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 134ms/step - accuracy: 0.6983 - loss: 0.8684 - val_accuracy: 0.5544 - val_loss: 1.3134
# Epoch 7/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.7727 - loss: 0.7618 - val_accuracy: 0.5158 - val_loss: 1.4089
# Epoch 8/15
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 134ms/step - accuracy: 0.8113 - loss: 0.6039 - val_accuracy: 0.5333 - val_loss: 1.3280
