# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_dir = "/content/drive/MyDrive/DS340_Final_Project/augmented_spectrograms_noise/noise_0.05"

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Image dimensions
IMG_HEIGHT, IMG_WIDTH = 128, 128
BATCH_SIZE = 32

# Create data generators
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

val_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 814 images belonging to 8 classes.
# Found 198 images belonging to 8 classes.

# %%
from tensorflow.keras import layers
from tensorflow import keras
input_shape = (128, 128, 3)

# %%
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
        layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
        layers.Conv2D(128, (3, 3), activation='relu'),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(128, activation='relu'),
        layers.Dense(8, activation='softmax'),
    ]
)

# %%
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

import keras.callbacks
callbacks = [
    keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)  # Quit after 3 rounds of no validation loss improvement
]

model.fit(train_generator, epochs=15, validation_data=val_generator, callbacks=callbacks)
# Out:
# Epoch 1/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 240ms/step - accuracy: 0.1948 - loss: 6.9518 - val_accuracy: 0.2121 - val_loss: 1.7654
# Epoch 2/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.2424 - loss: 1.7141 - val_accuracy: 0.2323 - val_loss: 1.8027
# Epoch 3/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.2806 - loss: 1.6458 - val_accuracy: 0.3232 - val_loss: 1.6608
# Epoch 4/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.3544 - loss: 1.5858 - val_accuracy: 0.3232 - val_loss: 1.7204
# Epoch 5/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.3344 - loss: 1.5386 - val_accuracy: 0.2929 - val_loss: 1.7860
# Epoch 6/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.4224 - loss: 1.4844 - val_accuracy: 0.3990 - val_loss: 1.5114
# Epoch 7/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.5214 - loss: 1.2402 - val_accuracy: 0.5253 - val_loss: 1.2527
# Epoch 8/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.6961 - loss: 0.9005 - val_accuracy: 0.6162 - val_loss: 1.1029
# Epoch 9/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.8054 - loss: 0.5265 - val_accuracy: 0.7121 - val_loss: 0.8115
# Epoch 10/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.7890 - loss: 0.6353 - val_accuracy: 0.6919 - val_loss: 0.8686
# Epoch 11/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.8574 - loss: 0.3764 - val_accuracy: 0.7677 - val_loss: 0.6626
# Epoch 12/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.9107 - loss: 0.2598 - val_accuracy: 0.7626 - val_loss: 0.7450
# Epoch 13/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.9307 - loss: 0.2020 - val_accuracy: 0.7677 - val_loss: 0.6738
# Epoch 14/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.9678 - loss: 0.0970 - val_accuracy: 0.7576 - val_loss: 0.8045

# %%
model2 = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
        layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(128, (3, 3), activation='relu'),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(128, activation='relu'),
        layers.Dense(8, activation='softmax'),
    ]
)

# %%
model2.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

import keras.callbacks
callbacks = [
    keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)  # Quit after 3 rounds of no validation loss improvement
]

model2.fit(train_generator, epochs=15, validation_data=val_generator, callbacks=callbacks)
# Out:
# Epoch 1/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 224ms/step - accuracy: 0.1740 - loss: 2.5082 - val_accuracy: 0.2828 - val_loss: 1.6891
# Epoch 2/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.3021 - loss: 1.6454 - val_accuracy: 0.2525 - val_loss: 1.6891
# Epoch 3/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.3223 - loss: 1.5472 - val_accuracy: 0.2929 - val_loss: 1.6704
# Epoch 4/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.3899 - loss: 1.5235 - val_accuracy: 0.3687 - val_loss: 1.6095
# Epoch 5/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.4664 - loss: 1.3485 - val_accuracy: 0.4495 - val_loss: 1.3723
# Epoch 6/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.6387 - loss: 0.9602 - val_accuracy: 0.6010 - val_loss: 1.0681
# Epoch 7/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.7421 - loss: 0.6985 - val_accuracy: 0.6212 - val_loss: 1.0860
# Epoch 8/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.7748 - loss: 0.5673 - val_accuracy: 0.6818 - val_loss: 0.8471
# Epoch 9/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.8647 - loss: 0.3889 - val_accuracy: 0.7020 - val_loss: 0.9217
# Epoch 10/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.8841 - loss: 0.3265 - val_accuracy: 0.6717 - val_loss: 0.7799
# Epoch 11/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.9281 - loss: 0.2282 - val_accuracy: 0.7323 - val_loss: 0.7124
# Epoch 12/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.9393 - loss: 0.1729 - val_accuracy: 0.7626 - val_loss: 0.5650
# Epoch 13/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.9484 - loss: 0.1582 - val_accuracy: 0.7323 - val_loss: 0.7507
# Epoch 14/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.9803 - loss: 0.0859 - val_accuracy: 0.7374 - val_loss: 0.7318
# Epoch 15/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.9796 - loss: 0.0779 - val_accuracy: 0.6313 - val_loss: 1.2058

# %%
model3 = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
        layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
        layers.Conv2D(128, (3, 3), activation='relu'),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(128, activation='relu'),
        layers.Dense(8, activation='softmax'),
    ]
)

# %%
model3.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

import keras.callbacks
callbacks = [
    keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)  # Quit after 3 rounds of no validation loss improvement
]

model3.fit(train_generator, epochs=15, validation_data=val_generator, callbacks=callbacks)
# Out:
# Epoch 1/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 230ms/step - accuracy: 0.1796 - loss: 2.4885 - val_accuracy: 0.2525 - val_loss: 1.6846
# Epoch 2/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.3331 - loss: 1.5923 - val_accuracy: 0.3182 - val_loss: 1.5584
# Epoch 3/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.4175 - loss: 1.4068 - val_accuracy: 0.5152 - val_loss: 1.3215
# Epoch 4/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.6580 - loss: 0.9484 - val_accuracy: 0.6061 - val_loss: 1.0975
# Epoch 5/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.7503 - loss: 0.6995 - val_accuracy: 0.7222 - val_loss: 0.8979
# Epoch 6/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.8058 - loss: 0.5383 - val_accuracy: 0.6465 - val_loss: 1.0785
# Epoch 7/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - accuracy: 0.8686 - loss: 0.3710 - val_accuracy: 0.7121 - val_loss: 0.6880
# Epoch 8/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.9142 - loss: 0.2519 - val_accuracy: 0.6364 - val_loss: 0.9840
# Epoch 9/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.9206 - loss: 0.2025 - val_accuracy: 0.7172 - val_loss: 0.8025
# Epoch 10/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.9604 - loss: 0.1168 - val_accuracy: 0.7121 - val_loss: 1.0095

# %%
model4 = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
        layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
        layers.Conv2D(128, (3, 3), activation='relu'),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(256, activation='relu'),
        layers.Dense(128, activation='relu'),
        layers.Dense(8, activation='softmax'),
    ]
)

# %%
model4.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

import keras.callbacks
callbacks = [
    keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)  # Quit after 3 rounds of no validation loss improvement
]

model4.fit(train_generator, epochs=15, validation_data=val_generator, callbacks=callbacks)
# Out:
# Epoch 1/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 11s 271ms/step - accuracy: 0.1879 - loss: 2.0424 - val_accuracy: 0.2121 - val_loss: 1.8214
# Epoch 2/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.2580 - loss: 1.7373 - val_accuracy: 0.2929 - val_loss: 1.7523
# Epoch 3/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.3848 - loss: 1.5296 - val_accuracy: 0.3889 - val_loss: 1.7643
# Epoch 4/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 178ms/step - accuracy: 0.5091 - loss: 1.2996 - val_accuracy: 0.4495 - val_loss: 1.5644
# Epoch 5/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.6107 - loss: 1.0164 - val_accuracy: 0.5859 - val_loss: 1.0412
# Epoch 6/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 174ms/step - accuracy: 0.7569 - loss: 0.6834 - val_accuracy: 0.6414 - val_loss: 0.9101
# Epoch 7/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.8326 - loss: 0.4962 - val_accuracy: 0.6919 - val_loss: 0.7524
# Epoch 8/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.8757 - loss: 0.3190 - val_accuracy: 0.6818 - val_loss: 0.7444
# Epoch 9/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.8997 - loss: 0.3136 - val_accuracy: 0.6566 - val_loss: 1.1360
# Epoch 10/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.9457 - loss: 0.1824 - val_accuracy: 0.7374 - val_loss: 0.7153
# Epoch 11/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.9724 - loss: 0.1131 - val_accuracy: 0.7121 - val_loss: 1.0124
# Epoch 12/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.9676 - loss: 0.0862 - val_accuracy: 0.6970 - val_loss: 1.2718
# Epoch 13/15
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.9808 - loss: 0.0672 - val_accuracy: 0.6162 - val_loss: 1.8495
